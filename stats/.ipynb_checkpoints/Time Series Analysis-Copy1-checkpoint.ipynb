# %% [markdown]
# # Time Series Analysis
#
# AirPassengers is a dataset with the number of passengers from international airlines between 1949 to 1960.

# %%
### create a time-series dataset based on the data

dts <- ts(nottem, start=c(1920,1), end=c(1939,12), frequency=12)

# %%
## change the size of the graphs
options(repr.plot.width = 6, repr.plot.height = 6)
plot(dts)
# Out:
# plot without title

# %%
dts
head(dts,20)
# Out:
#      Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 1920 40.6 40.8 44.4 46.7 54.1 58.5 57.7 56.4 54.3 50.5 42.9 39.8
# 1921 44.2 39.8 45.1 47.0 54.1 58.7 66.3 59.9 57.0 54.2 39.7 42.8
# 1922 37.5 38.7 39.5 42.1 55.7 57.8 56.8 54.3 54.3 47.1 41.8 41.7
# 1923 41.8 40.1 42.9 45.8 49.2 52.7 64.2 59.6 54.4 49.2 36.3 37.6
# 1924 39.3 37.5 38.3 45.5 53.2 57.7 60.8 58.2 56.4 49.8 44.4 43.6
# 1925 40.0 40.5 40.8 45.1 53.8 59.4 63.5 61.0 53.0 50.0 38.1 36.3
# 1926 39.2 43.4 43.4 48.9 50.6 56.8 62.5 62.0 57.5 46.7 41.6 39.8
# 1927 39.4 38.5 45.3 47.1 51.7 55.0 60.4 60.5 54.7 50.3 42.3 35.2
# 1928 40.8 41.1 42.8 47.3 50.9 56.4 62.2 60.5 55.4 50.2 43.0 37.3
# 1929 34.8 31.3 41.0 43.9 53.1 56.9 62.5 60.3 59.8 49.2 42.9 41.9
# 1930 41.6 37.1 41.2 46.9 51.2 60.4 60.1 61.6 57.0 50.9 43.0 38.8
# 1931 37.1 38.4 38.4 46.5 53.5 58.4 60.6 58.2 53.8 46.6 45.5 40.6
# 1932 42.4 38.4 40.3 44.6 50.9 57.0 62.1 63.5 56.3 47.3 43.6 41.8
# 1933 36.2 39.3 44.5 48.7 54.2 60.8 65.5 64.9 60.1 50.2 42.1 35.8
# 1934 39.4 38.2 40.4 46.9 53.4 59.6 66.5 60.4 59.2 51.2 42.8 45.8
# 1935 40.0 42.6 43.5 47.1 50.0 60.5 64.6 64.0 56.8 48.6 44.2 36.4
# 1936 37.3 35.0 44.0 43.9 52.7 58.6 60.0 61.1 58.1 49.6 41.6 41.3
# 1937 40.8 41.0 38.4 47.4 54.1 58.6 61.4 61.8 56.3 50.9 41.4 37.1
# 1938 42.1 41.2 47.3 46.6 52.4 59.0 59.6 60.4 57.0 50.7 47.8 39.2
# 1939 39.4 40.9 42.4 47.8 52.4 58.0 60.7 61.8 58.2 46.7 46.6 37.8
#  [1] 40.6 40.8 44.4 46.7 54.1 58.5 57.7 56.4 54.3 50.5 42.9 39.8 44.2 39.8 45.1
# [16] 47.0 54.1 58.7 66.3 59.9

# %% [markdown]
# ## Time Series Decomposition

# %%
stationary_dts <- decompose(dts) ### the decompose seperate the data into 4 categories. (the data the trend the seasonal and the noize. We look at the seasonally because it doesnt change, and after the running we can see if it is stasionary. if it is without a trend

# %%
plot(stationary_dts)
# Out:
# plot without title

# %% [markdown]
# ### Predicting the future tendency using ARIMA regression
#
# To be able to run the ARIMA model, we have to determine three parameters: p, d ,q. They derivative parts of the AR-I-MA. The p part is obtined by examining the autocorrelation of the series. We need to determine the correct time lag to define the parameters of the model by running the autocorrelation (acf) and partial autocorrelation (pacf) functions.

# %%
acf(dts) # we start with the acf and try to see what is the last line in which it doesnt cross the blue line . if all the lines cross the blue line we go to the "pacf"
# Out:
# Plot with title “Series  dts”

# %%
pacf(dts) # we chose the line as in the acf .  we do not really need these methodology because we have the outo_ARIMA wich check all the posibilities of the p d q and gives as the best model by the AIC
# Out:
# Plot with title “Series  dts”

# %%
dts_arima <- arima(dts, order=c(3,0,0)) ####in this way we enter the data of the p d q by myself by the last line wich doesnt cross the line 
dts_arima
# Out:
# Call:
# arima(x = dts, order = c(3, 0, 0))
#
# Coefficients:
#          ar1     ar2      ar3  intercept
#       0.9635  0.1300  -0.5591    49.0212
# s.e.  0.0538  0.0826   0.0538     0.4604
#
# sigma^2 estimated as 10.93:  log likelihood = -629.1,  aic = 1268.2

# %%
library(forecast) ###the forcast is the function in order to predict
dts_fit <- forecast(dts_arima)
dts_fit
# Out:
#          Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# Jan 1940       39.19281 34.95530 43.43033 32.71209 45.67354
# Feb 1940       39.44641 33.56211 45.33072 30.44714 48.44568
# Mar 1940       44.79161 37.39322 52.19000 33.47675 56.10647
# Apr 1940       49.19583 41.39205 56.99962 37.26097 61.13069
# May 1940       53.99239 46.15795 61.82684 42.01064 65.97415
# Jun 1940       56.19808 48.21808 64.17809 43.99372 68.40244
# Jul 1940       56.48463 48.04093 64.92832 43.57111 69.39815
# Aug 1940       54.36592 45.32079 63.41105 40.53258 68.19925
# Sep 1940       51.12875 41.70753 60.54997 36.72024 65.53726
# Oct 1940       47.57416 38.04684 57.10149 33.00337 62.14495
# Nov 1940       44.91301 35.38511 54.44091 30.34135 59.48467
# Dec 1940       43.69667 34.06799 53.32536 28.97088 58.42247
# Jan 1941       44.16599 34.30128 54.03071 29.07921 59.25277
# Feb 1941       45.94776 35.84310 56.05243 30.49401 61.40151
# Mar 1941       48.40547 38.17318 58.63777 32.75653 64.05442
# Apr 1941       50.74269 40.49055 60.99484 35.06339 66.42200
# May 1941       52.31797 42.05803 62.57792 36.62674 68.00920
# Jun 1941       52.76558 42.43534 63.09583 36.96684 68.56433
# Jul 1941       52.09502 41.64650 62.54353 36.11539 68.07464
# Aug 1941       50.62647 40.07875 61.17419 34.49512 66.75781
# Sep 1941       48.87413 38.28622 59.46205 32.68131 65.06695
# Oct 1941       47.36976 36.77997 57.95955 31.17407 63.56545
# Nov 1941       46.51351 35.91215 57.11486 30.30014 62.72688
# Dec 1941       46.47259 35.82729 57.11789 30.19201 62.75317

# %% [markdown]
# On our data, acf doesn't show us a useful value for our parameters, as all the data is over the confidence values (blue dotted lines).

# %% [markdown]
# On the other hand, the pacf function show that the first lag is positive and outside than the confidence levels (blue dotted line). The second lag was negative and was outside the confidence levels. The third and following lags were lower and inside the confidence levels. Thus, the value that define our time lag for the model is 2.
#
# The d parameter is defined by the integrative part of the model and is defined by the difference subtracting its current and previous values d times.
#
# The q part of the model is determined by the moving average (MA) of the model.
#
# We will begin assumming the d and q as zero.
#
# Finally, having the required parameters, we proced to run the arima model as:
# <code> arima(data, order=c(p,d,q)) </code>

# %% [markdown]
# The ARIMA model gives us the formula for calculating the next value in the data series. The values of the betas are provided by the ar1 and ar2 variables. the formula is like most of the regressions we have learned:
#
# <code> Xt = (1.2831 * Xt-1) + (-0.3322 * Xt-2) + 280.4696 </code>

# %% [markdown]
# ## Forecasting using the ARIMA predictive model

# %%
plot(dts_fit)
# Out:
# Plot with title “Forecasts from ARIMA(3,0,0) with non-zero mean”

# %% [markdown]
# For finding the optimal ARIMA model we have to change the values of d and q and compare the models using the AIC statistic (the less the best).
#
# R have a function that search for the best model automatically: <i> auto.arima </i>

# %%
dts_autoarima <- auto.arima(dts)
dts_autoarima
# Out:
# Series: dts
# ARIMA(1,0,2)(1,1,2)[12] with drift
#
# Coefficients:
#          ar1     ma1     ma2     sar1     sma1     sma2  drift
#       0.1562  0.0898  0.1113  -0.5324  -0.4925  -0.2391  0.004
# s.e.  0.3699  0.3651  0.1139   0.1911   0.2071   0.1880  0.004
#
# sigma^2 estimated as 5.22:  log likelihood=-516.48
# AIC=1048.96   AICc=1049.62   BIC=1076.4

# %%
dts_autoforecast <- forecast(dts_autoarima)
dts_autoforecast
# Out:
#          Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# Jan 1940       40.35893 37.43091 43.28694 35.88091 44.83694
# Feb 1940       39.44870 36.43344 42.46396 34.83726 44.06014
# Mar 1940       43.45911 40.41218 46.50605 38.79923 48.11899
# Apr 1940       46.61631 43.56861 49.66401 41.95525 51.27737
# May 1940       52.81297 49.76525 55.86069 48.15189 57.47406
# Jun 1940       59.14794 56.10022 62.19566 54.48685 63.80903
# Jul 1940       61.99079 58.94307 65.03851 57.32970 66.65188
# Aug 1940       61.58756 58.53983 64.63528 56.92647 66.24864
# Sep 1940       57.38818 54.34045 60.43590 52.72709 62.04926
# Oct 1940       50.29230 47.24458 53.34002 45.63121 54.95339
# Nov 1940       44.15271 41.10499 47.20044 39.49163 48.81380
# Dec 1940       39.72837 36.68065 42.77609 35.06729 44.38946
# Jan 1941       39.94022 36.89165 42.98879 35.27784 44.60260
# Feb 1941       40.05869 37.01007 43.10731 35.39622 44.72115
# Mar 1941       42.73850 39.68986 45.78715 38.07601 47.40100
# Apr 1941       47.08000 44.03136 50.12864 42.41750 51.74249
# May 1941       52.81234 49.76370 55.86098 48.14984 57.47483
# Jun 1941       58.86558 55.81694 61.91422 54.20308 63.52807
# Jul 1941       61.87963 58.83099 64.92827 57.21714 66.54213
# Aug 1941       61.83258 58.78393 64.88122 57.17008 66.49507
# Sep 1941       57.68608 54.63743 60.73472 53.02358 62.34857
# Oct 1941       49.24880 46.20015 52.29744 44.58630 53.91129
# Nov 1941       44.56120 41.51256 47.60984 39.89871 49.22370
# Dec 1941       39.15417 36.10553 42.20281 34.49167 43.81666

# %%
plot(dts_autoforecast)
# Out:
# Plot with title “Forecasts from ARIMA(1,0,2)(1,1,2)[12] with drift”
